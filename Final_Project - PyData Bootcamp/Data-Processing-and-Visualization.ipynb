# %% [markdown]
# ### Importing data librabries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %matplotlib inline       

mpl.style.use('seaborn')

# %%
covid_19 = pd.read_csv('PA_singlestate_timeseries - PA_singlestate_timeseries.csv', index_col='date')
covid_19.head()
# Out:
#            country state  county  fips  lat  long          locationId  \
# date
# 2020-03-02      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2020-03-03      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2020-03-04      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2020-03-05      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2020-03-06      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
#
#             actuals.cases  actuals.deaths  actuals.positiveTests  ...  \
# date                                                              ...
# 2020-03-02            NaN             NaN                    NaN  ...
# 2020-03-03            NaN             NaN                    1.0  ...
# 2020-03-04            NaN             NaN                    1.0  ...
# 2020-03-05            NaN             NaN                    2.0  ...
# 2020-03-06            2.0             0.0                    7.0  ...
#
# ...

# %% [markdown]
# ### Overview of the dataset

# %%
covid_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   date                                    501 non-null    object
#  1   country                                 501 non-null    object
#  2   state                                   501 non-null    object
#  3   county                                  0 non-null      float64
#  4   fips                                    501 non-null    int64
#  5   lat                                     0 non-null      float64
#  6   long                                    0 non-null      float64
#  7   locationId                              501 non-null    object
#  8   actuals.cases                           492 non-null    float64
#  9   actuals.deaths                          492 non-null    float64
# ...

# %% [markdown]
# ###  General Description of the dataset
#
# #### - The dataset is made up for covid cases recorded in a particular state in the US
# #### - The dataset also contains information on vaccinations
# #### - The dataset comprises of information on the infrastructure like beds and ICU that was used during the outrbeak

# %% [markdown]
# ### The number of entries
#
# #### - The dataset has 39 columns and 500 rows
# #### - The dataset has some missing values and duplicates

# %% [markdown]
# ### COVID information on the day of January, 3rd, 2021

# %%
print(date(2021,1,3).strftime('%B-%d-%Y'))
# Out:
# January-03-2021

# %%
c_info_today = covid_19.loc['2021-03-20']
print(c_info_today)
# Out:
# country                                                   US
# state                                                     PA
# county                                                   NaN
# fips                                                      42
# lat                                                      NaN
# long                                                     NaN
# locationId                                iso1:us#iso2:us-pa
# actuals.cases                                       989336.0
# actuals.deaths                                       24841.0
# actuals.positiveTests                              1046012.0
# actuals.negativeTests                             10975268.0
# actuals.contactTracers                                  1508
# actuals.hospitalBeds.capacity                            NaN
# actuals.hospitalBeds.currentUsageTotal               24941.0
# actuals.hospitalBeds.currentUsageCovid                2043.0
# ...

# %%
dash_board= c_info_today[['state','actuals.cases','actuals.deaths','actuals.newCases','actuals.newDeaths','metrics.caseDensity',
                  'metrics.vaccinationsInitiatedRatio','actuals.vaccinationsInitiated',
                'metrics.vaccinationsCompletedRatio','actuals.vaccinationsCompleted']]
sss
# Out:
# state                                        PA
# actuals.cases                          989336.0
# actuals.deaths                          24841.0
# actuals.newCases                         3741.0
# actuals.newDeaths                          24.0
# metrics.caseDensity                        22.6
# metrics.vaccinationsInitiatedRatio        0.244
# actuals.vaccinationsInitiated         3124834.0
# metrics.vaccinationsCompletedRatio        0.125
# actuals.vaccinationsCompleted         1596830.0
# Name: 2021-03-20, dtype: object

# %%
pd.DataFrame(dash_board)
# Out:
#                                    2021-03-20
# state                                      PA
# actuals.cases                        989336.0
# actuals.deaths                        24841.0
# actuals.newCases                       3741.0
# actuals.newDeaths                        24.0
# metrics.caseDensity                      22.6
# metrics.vaccinationsInitiatedRatio      0.244
# actuals.vaccinationsInitiated       3124834.0
# metrics.vaccinationsCompletedRatio      0.125
# actuals.vaccinationsCompleted       1596830.0

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ##### Constructing graphs to show the relationship between actual covid cases and actual vaccinations completed. Because cases and vaccinations were recorded cummulatively over the years, we take the last day covid cases and vaccination completed were recorded which is 23-06-2021

# %%
aa_06_21 = covid_19.loc['2021-06-23']
ac_06_21 = aa_06_21['actuals.cases']


avc_06_21 = aa_06_21['actuals.vaccinationsCompleted']
avc_06_21

covid_06_21 = [ac_06_21, avc_06_21]
covid_06_21
# Out:
# [1215374.0, 6235274.0]

# %%
plt.figure(figsize=(7,8))
names = ['Actual Covid Cases', 'Actual Vaccinations Completed']
plt.pie(x= covid_06_21, labels=names, colors=['Red','Green'],  autopct= '%.1f%%')
plt.title('Actual Covid Cases anad Actual Vaccinations Completed as at 23rd June 2021')
# Out:
# Text(0.5, 1.0, 'Actual Covid Cases anad Actual Vaccinations Completed as at 23rd June 2021')

# %% [markdown]
# ### From the diagram above, we can observe that as at 23rd June 2021, most of the residents of PA state had been completely vaccinated so it reduced the number of covid cases.

# %%
c_trend = covid_19.loc['2021-01-14': '2021-06-23']
c_trend
# Out:
#            country state  county  fips  lat  long          locationId  \
# date
# 2021-01-14      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2021-01-15      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2021-01-16      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2021-01-17      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2021-01-18      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# ...            ...   ...     ...   ...  ...   ...                 ...
# 2021-06-19      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2021-06-20      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2021-06-21      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2021-06-22      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2021-06-23      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
#
#             actuals.cases  actuals.deaths  actuals.positiveTests  ...  \
# ...

# %% [markdown]
# ##### We will construct a plot to see the relationship between actual covid cases and actual vaccinations completed for the given time range. We will also see the effect vaccinations completed have on covid cases.

# %%
plt.figure(figsize= (10,8))
sns.scatterplot(x='actuals.cases', y= 'actuals.vaccinationsCompleted', data= bbb, hue= 'actuals.cases', palette= 'Blues_r')
plt.title('Covid Cases and Vaccinations Completed from 14TH January, 2021 - 23RD June, 2021')
# Out:
# Text(0.5, 1.0, 'Covid Cases and Vaccinations Completed from 14TH January, 2021 - 23RD June, 2021')

# %% [markdown]
# ### Looking at the trend from the day vaccinations were completed were recorded it can  be observed from the diagram above that there is a weak positive relationship between actual covid cases and actual vaccinations completed. This means that though covid cases were rising cummulatively, the daily covid cases recorded was declining.

# %% [markdown]
# ### Recommendation

# %% [markdown]
# #### From the analysis made, I recommend that more vaccinations should  be done since it can be observed that more vaccinations reduces the number of covid cases.
